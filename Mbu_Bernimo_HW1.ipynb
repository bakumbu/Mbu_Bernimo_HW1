# %% [markdown]
# # Homework 1: Python Basics
# #### **Bernimo Mbu M21036552**
# #### *Data-101-22885*
#
# #### **Things I am Excited to Learn**
# 1. Data Cleaning
# 2. What Processed Data can be used for
# 3. More Coding Techniques Via Python
#
# # Classes
#
# | Class | Credits | Day/Time | Location |
# |:-----:|:--------|:---------|:---------|
# |Data Visualization|3|Tuesday/Thursday|Zoom|
# |Introduction to Data Science|3|Tuesday/Thursday|Science Center, Room 362|
# |Introduction to Philosophy|3|Remote|Remote|

# %%
product = 'Stellar Jade'
price = 19.99
stock = 65 

price = 50 - int(price)
print(price)

print(f"We have {stock} units of {product} available at {price} each")
# Out:
# 31
# We have 65 units of Stellar Jade available at 31 each

# %%
result = price*stock
print(result)

print(result > 500)
# Out:
# 2015
# True

# %% [markdown]
# 1. I used the same code from the markdown activity to create my table and headings, which was fairly simple
# 2. For the products, I referenced digital currency from a game I play for both the product name and price. As for the conversion I just chose a random number
# 3. Part 3 was very easy. It is just normal multiplication and comparisons, but using named variables instead of numbers
